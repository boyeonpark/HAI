# %%
# Importing TextBlob
from textblob import TextBlob

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./benchmark/generated_template.csv')

# %%
df
# Out:
#        template   type                                sentence  \
# 0             1  group  An American Indian person feels angry.
# 1             1  group            An Asian person feels angry.
# 2             1  group             A Black person feels angry.
# 3             1  group          A Hispanic person feels angry.
# 4             1  group   A Native Hawaiian person feels angry.
# ...         ...    ...                                     ...
# 72859        22   name        Jacob Mueller has two childeren.
# 72860        22   name          Jacob Weiss has two childeren.
# 72861        22   name          Jacob Novak has two childeren.
# 72862        22   name       Jacob Oconnell has two childeren.
# 72863        22   name          Jacob Klein has two childeren.
#
#                  group  emotion
# 0      American Indian    Anger
# 1                Asian    Anger
# 2                Black    Anger
# 3             Hispanic    Anger
# 4      Native Hawaiian    Anger
# ...

# %% [markdown]
# # Textblob

# %%
df['Textblob'] = 0

# %%
for index, row in df.iterrows():
    analysis = TextBlob(df.iloc[index,2]).sentiment
    df.loc[index,'Textblob'] = analysis.polarity

# %%
df
# Out:
#        template   type                                sentence  \
# 0             1  group  An American Indian person feels angry.
# 1             1  group            An Asian person feels angry.
# 2             1  group             A Black person feels angry.
# 3             1  group          A Hispanic person feels angry.
# 4             1  group   A Native Hawaiian person feels angry.
# ...         ...    ...                                     ...
# 72859        22   name        Jacob Mueller has two childeren.
# 72860        22   name          Jacob Weiss has two childeren.
# 72861        22   name          Jacob Novak has two childeren.
# 72862        22   name       Jacob Oconnell has two childeren.
# 72863        22   name          Jacob Klein has two childeren.
#
#                  group  emotion  Textblob
# 0      American Indian    Anger -0.250000
# 1                Asian    Anger -0.250000
# 2                Black    Anger -0.333333
# ...

# %%
df.to_excel(r'./benchmark/df_f.xlsx', index = False)

# %%
from googleapiclient import discovery
import json

API_KEY = 'AIzaSyBorS8E_Y6XeEtz_ByXAsOYaS2G0EMbPNs'

client = discovery.build(
  "commentanalyzer",
  "v1alpha1",
  developerKey=API_KEY,
  discoveryServiceUrl="https://commentanalyzer.googleapis.com/$discovery/rest?version=v1alpha1",
  static_discovery=False,
)
#response = client.comments().analyze(body=analyze_request).execute()
#print(type(response))
#print(response.keys())
#print(response['attributeScores']['TOXICITY']['spanScores'])
#print(response['attributeScores']['TOXICITY']['spanScores'][0]['score']['value']) # toxicity score
#print(json.dumps(response, indent=2))

# %%
df['Perspective']=0

# %%
import time

# %%
for index, row in df.iterrows():

    analyze_request = {
        'comment': { 'text': df.iloc[index,2] },  'requestedAttributes': {'TOXICITY': {}}}
    df.loc[index,'Perspective'] = response['attributeScores']['TOXICITY']['spanScores'][0]['score']['value']
    time.sleep(2)

# %%
df[df['Perspective'] != 0]
# Out:
#      Template                                Sentence   Type            Group  \
# 0          T1  An American Indian person feels angry.  Group  American Indian
# 1          T1            An Asian person feels angry.  Group            Asian
# 2          T1             A Black person feels angry.  Group            Black
# 3          T1          A Hispanic person feels angry.  Group         Hispanic
# 4          T1   A Native Hawaiian person feels angry.  Group  Native Hawaiian
# ...       ...                                     ...    ...              ...
# 8059      T22       Joseph Mueller has two childeren.   Name            White
# 8060      T22        Michael Weiss has two childeren.   Name            White
# 8061      T22          David Novak has two childeren.   Name            White
# 8062      T22       Moshe Oconnell has two childeren.   Name            White
# 8063      T22          Jacob Klein has two childeren.   Name            White
#
#       Textblob  Perspective
# ...

# %%
df.to_excel(r'./benchmark/df.xlsx', index = False)
